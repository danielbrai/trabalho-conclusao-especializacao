# %%
import json
import pandas as pd
import re
import math

# %%
with open('data/default-cards-20230612090651.json') as f:
    cards_json = json.load(f)

# %%
len(cards_json)
# Out:
# 83971

# %%
double_faced_cards = []

for card in cards_json:
    if '//' in card['name']:
        double_faced_cards.append(card)

# %%
len(double_faced_cards)
# Out:
# 2895

# %% [markdown]
# ## Preparação do conjunto de dados

# %% [markdown]
# ### Carga e tratamento inicial do conjunto de dados de cartas

# %%
pd.set_option('display.max_columns', None)

# %%
raw_cards = pd.read_json('data/default-cards-20230612090651.json')
print(f'Starter raw card set length ---> : {len(raw_cards.index)}')
# Out:
# Starter raw card set length ---> : 83971

# %%
card_set_drop_reprints = raw_cards.query('reprint != True')
print(f'Number of removed cards ---> : {len(raw_cards.index) - len(card_set_drop_reprints.index)}')
print(f'Current card set length ---> : {len(card_set_drop_reprints.index)}')
# Out:
# Number of removed cards ---> : 50057
# Current card set length ---> : 33914

# %%
card_set_drop_digital_content = card_set_drop_reprints.query('digital != True')
print(f'Number of removed cards ---> : {len(card_set_drop_reprints.index) - len(card_set_drop_digital_content.index)}')
print(f'Current card set length ---> : {len(card_set_drop_digital_content.index)}')
# Out:
# Number of removed cards ---> : 746
# Current card set length ---> : 33168

# %%
card_set_drop_tokens = card_set_drop_digital_content.query('not type_line.str.contains("Token")')
print(f'Current card set length without tokens ---> : {len(card_set_drop_tokens.index)}')
# Out:
# Current card set length without tokens ---> : 32535

# %%
card_set_drop_tokens.columns.values.tolist()
# Out:
# ['object',
#  'id',
#  'oracle_id',
#  'multiverse_ids',
#  'mtgo_id',
#  'mtgo_foil_id',
#  'tcgplayer_id',
#  'cardmarket_id',
#  'name',
#  'lang',
#  'released_at',
#  'uri',
#  'scryfall_uri',
#  'layout',
#  'highres_image',
#  'image_status',
#  'image_uris',
#  'mana_cost',
#  'cmc',
#  'type_line',
#  'oracle_text',
#  'power',
#  'toughness',
#  'colors',
#  'color_identity',
#  'keywords',
#  'legalities',
#  'games',
#  'reserved',
#  'foil',
#  'nonfoil',
#  'finishes',
#  'oversized',
#  'promo',
#  'reprint',
#  'variation',
#  'set_id',
#  'set',
#  'set_name',
#  'set_type',
#  'set_uri',
#  'set_search_uri',
#  'scryfall_set_uri',
#  'rulings_uri',
#  'prints_search_uri',
#  'collector_number',
#  'digital',
#  'rarity',
#  'flavor_text',
#  'card_back_id',
#  'artist',
#  'artist_ids',
#  'illustration_id',
#  'border_color',
#  'frame',
#  'full_art',
#  'textless',
#  'booster',
#  'story_spotlight',
#  'edhrec_rank',
#  'penny_rank',
#  'prices',
#  'related_uris',
#  'all_parts',
#  'promo_types',
#  'arena_id',
#  'preview',
#  'security_stamp',
#  'produced_mana',
#  'watermark',
#  'frame_effects',
#  'loyalty',
#  'printed_name',
#  'card_faces',
#  'tcgplayer_etched_id',
#  'attraction_lights',
#  'color_indicator',
#  'variation_of',
#  'life_modifier',
#  'hand_modifier',
#  'printed_type_line',
#  'printed_text',
#  'content_warning',
#  'flavor_name']

# %%
undesired_columns = [
    'object',
    'multiverse_ids',
    'mtgo_id',
    'mtgo_foil_id',
    'tcgplayer_id',
    'cardmarket_id',
    'name',
    'lang',
    'released_at',
    'uri',
    'scryfall_uri',
    'layout',
    'highres_image',
    'image_status',
    'image_uris',
    'games',
    'foil',
    'nonfoil',
    'finishes',
    'oversized',
    'promo',
    'variation',
    'set_id',
    'set',
    'set_name',
    'set_type',
    'set_uri',
    'set_search_uri',
    'scryfall_set_uri',
    'rulings_uri',
    'prints_search_uri',
    'collector_number',
    'card_back_id',
    'artist',
    'artist_ids',
    'illustration_id',
    'border_color',
    'frame',
    'full_art',
    'textless',
    'booster',
    'story_spotlight',
    'prices',
    'related_uris',
    'all_parts',
    'promo_types',
    'arena_id',
    'preview',
    'security_stamp',
    'watermark',
    'frame_effects',
    'card_faces',
    'tcgplayer_etched_id',
    'attraction_lights',
    'variation_of',
    'printed_type_line',
    'printed_text',
    'printed_name',
    'content_warning',
    'flavor_name',
    'reprint',
    'digital',
    'color_indicator'
]

# %%
card_set_cleaned_undesired_columns = card_set_drop_tokens.drop(columns=undesired_columns)
print(f'Total de colunas original ---> {card_set_drop_tokens.shape[1]} colunas')
print(f'Total de colunas após limpeza ---> {card_set_cleaned_undesired_columns.shape[1]} colunas')
print(f'Número de colunas removidas ---> {len(undesired_columns)} colunas')
# Out:
# Total de colunas original ---> 84 colunas
# Total de colunas após limpeza ---> 21 colunas
# Número de colunas removidas ---> 63 colunas

# %%
card_set_cleaned_undesired_columns.columns.values.tolist()
# Out:
# ['id',
#  'oracle_id',
#  'mana_cost',
#  'cmc',
#  'type_line',
#  'oracle_text',
#  'power',
#  'toughness',
#  'colors',
#  'color_identity',
#  'keywords',
#  'legalities',
#  'reserved',
#  'rarity',
#  'flavor_text',
#  'edhrec_rank',
#  'penny_rank',
#  'produced_mana',
#  'loyalty',
#  'life_modifier',
#  'hand_modifier']

# %%
card_set_without_duplicates = card_set_cleaned_undesired_columns.drop_duplicates(subset='oracle_id')
print(f'Total de cartas ANTES da eliminação das duplicatas ---> {len(card_set_cleaned_undesired_columns)}')
print(f'Total de cartas APÓS da eliminação das duplicatas ---> {len(card_set_without_duplicates)}')
print(f'número de duplicatas removidas ---> {len(card_set_cleaned_undesired_columns)-len(card_set_without_duplicates)}')
# Out:
# Total de cartas ANTES da eliminação das duplicatas ---> 32535
# Total de cartas APÓS da eliminação das duplicatas ---> 27736
# número de duplicatas removidas ---> 4799

# %%
mtg_card_types = [
    'Artifact',
    'Battle ',
    'Creature',
    'Enchantment',
    'Land',
    'Planeswalker',
    'Instant',
    'Sorcery'
]

card_set_standardized_types = card_set_without_duplicates[card_set_without_duplicates['type_line'].str.contains('|'.join(mtg_card_types))]
print(f'Total de cartas ANTES da eliminação de tipos não desejados ---> {len(card_set_without_duplicates)}')
print(f'Total de cartas APÓS da eliminação de tipos não desejados ---> {len(card_set_standardized_types)}')
print(f'Número de cartas com tipos não desejados removidas ---> {len(card_set_without_duplicates)-len(card_set_standardized_types)}')
# Out:
# Total de cartas ANTES da eliminação de tipos não desejados ---> 27736
# Total de cartas APÓS da eliminação de tipos não desejados ---> 26041
# Número de cartas com tipos não desejados removidas ---> 1695

# %%
double_faced_cards_dataset = card_set_standardized_types[card_set_standardized_types['type_line'].str.contains('//')]
double_faced_cards_dataset.shape
# Out:
# (544, 21)

# %%
def getDoublefacedCardData(card_id):
    card = next(x for x in cards_json if x['id'] == card_id)

    front_face = card['card_faces'][0]
    back_face = card['card_faces'][1]
    
    return (
        {
            'id': card['id'],
            'oracle_id': card['oracle_id'],
            'mana_cost': front_face['mana_cost'] if 'mana_cost' in front_face else None,
            'cmc': card['cmc'],
            'type_line': front_face['type_line'],
            'oracle_text': front_face['oracle_text'] if 'oracle_text' in front_face else None,
            'power': front_face['power'] if 'power' in front_face else None,
            'toughness': front_face['toughness'] if 'toughness' in front_face else None,
            'colors': front_face['colors'] if 'colors' in front_face else None,
            'color_identity': card['color_identity'],
            'keywords': card['keywords'],
            'legalities': card['legalities'],
            'reserved': card['reserved'],
            'rarity': card['rarity'],
            'flavor_text': front_face['flavor_text'] if 'flavor_text' in front_face else None,
            'produced_mana': front_face['loyalty'] if 'loyalty' in front_face else None,
            'loyalty': front_face['loyalty'] if 'loyalty' in front_face else None,
            'life_modifier': front_face['life_modifier'] if 'life_modifier' in front_face else None,
            'hand_modifier': front_face['hand_modifier'] if 'hand_modifier' in front_face else None
        },
        {
            'id': card['id'],
            'oracle_id': card['oracle_id'],
            'mana_cost': back_face['mana_cost'] if 'mana_cost' in back_face else None,
            'cmc': card['cmc'],
            'type_line': back_face['type_line'],
            'oracle_text': back_face['oracle_text'] if 'oracle_text' in back_face else None,
            'power': back_face['power'] if 'power' in back_face else None,
            'toughness': back_face['toughness'] if 'toughness' in back_face else None,
            'colors': back_face['colors'] if 'colors' in back_face else None,
            'color_identity': card['color_identity'],
            'keywords': card['keywords'],
            'legalities': card['legalities'],
            'reserved': card['reserved'],
            'rarity': card['rarity'],
            'flavor_text': back_face['flavor_text'] if 'flavor_text' in back_face else None,
            'produced_mana': back_face['loyalty'] if 'loyalty' in back_face else None,
            'loyalty': back_face['loyalty'] if 'loyalty' in back_face else None,
            'life_modifier': back_face['life_modifier'] if 'life_modifier' in back_face else None,
            'hand_modifier': back_face['hand_modifier'] if 'hand_modifier' in back_face else None
        }
    )

# %%
double_faced_cards_id_list = double_faced_cards_dataset.id.tolist()
print(f'Total de cartas com face dupla ---> { len(double_faced_cards_id_list)} cartas')
# Out:
# Total de cartas com face dupla ---> 544 cartas

# %%
double_faced_cards_splited = []

for id in double_faced_cards_id_list:
    double_faced_cards_splited.extend(getDoublefacedCardData(id))

print(f'Montante de cartas a ser adicionado ao dataframe ---> {len(double_faced_cards_splited)} cartas')
# Out:
# Montante de cartas a ser adicionado ao dataframe ---> 1088 cartas

# %%
# print(f'{dropped_double_faced_cards_dataset}')

cards_to_drop = card_set_standardized_types.loc[card_set_standardized_types['id'].isin(double_faced_cards_id_list)].index
total_cards_to_drop = len(cards_to_drop)
print(f'Número de registros a serem removidos ---> {total_cards_to_drop} cartas')

dropped_double_faced_cards_dataset = card_set_standardized_types.drop(cards_to_drop)

total_cards_after_drop  = len(dropped_double_faced_cards_dataset.index)
total_cards_before_drop = len(card_set_standardized_types.index)

print(f'Total de cartas ANTES da remoção das cartas com face dupla ---> {total_cards_before_drop} cartas')
print(f'Total de cartas APÓS da remoção das cartas com face dupla ---> {total_cards_after_drop} cartas')
print(f'Total de cartas cartas face dupla removidas ---> { total_cards_before_drop - total_cards_after_drop} cartas')

dropped_double_faced_cards_dataset._append(double_faced_cards)
dropped_double_faced_cards_dataset.shape
# Out:
# Número de registros a serem removidos ---> 544 cartas
# Total de cartas ANTES da remoção das cartas com face dupla ---> 26041 cartas
# Total de cartas APÓS da remoção das cartas com face dupla ---> 25497 cartas
# Total de cartas cartas face dupla removidas ---> 544 cartas
# (25497, 21)

# %%
final_cards_dataset = dropped_double_faced_cards_dataset.copy()
final_cards_dataset.shape
# Out:
# (25497, 21)

# %% [markdown]
# ### Carga e tratamento do conjunto de dados de regras expandidas

# %%
rules = pd.read_json('data/rulings-20230612090033.json')
rules
# Out:
#        object                             oracle_id source published_at  \
# 0      ruling  0004ebd0-dfd6-4276-b4a6-de0003e94237   wotc   2004-10-04
# 1      ruling  0007c283-5b7a-4c00-9ca1-b455c8dff8c3   wotc   2019-08-23
# 2      ruling  0007c283-5b7a-4c00-9ca1-b455c8dff8c3   wotc   2019-08-23
# 3      ruling  0007c283-5b7a-4c00-9ca1-b455c8dff8c3   wotc   2019-08-23
# 4      ruling  000e5d65-96c3-498b-bd01-72b1a1991850   wotc   2004-10-04
# ...       ...                                   ...    ...          ...
# 52331  ruling  fffdc2ac-bde4-4e4c-a5bd-0e6c6e49ad91   wotc   2017-07-14
# 52332  ruling  ffff90c3-63c4-4dee-a21d-6b2b113f4f80   wotc   2013-07-01
# 52333  ruling  ffff90c3-63c4-4dee-a21d-6b2b113f4f80   wotc   2013-07-01
# 52334  ruling  ffff90c3-63c4-4dee-a21d-6b2b113f4f80   wotc   2021-03-19
# 52335  ruling  ffff90c3-63c4-4dee-a21d-6b2b113f4f80   wotc   2021-03-19
#
#                                                  comment
# 0      If there are two of these on the battlefield, ...
# 1      The “commander tax” increases based on how man...
# 2      Certain cards in other sets with the partner k...
# 3      If your commander isn’t in the command zone (o...
# 4      The target loses just one of the listed abilit...
# ...                                                  ...
# 52331  You divide the damage as you activate Samut’s ...
# 52332  Abilities that Slivers grant, as well as power...
# 52333  If the creature type of a Sliver changes so it...
# 52334  Because damage remains marked on a creature un...
# 52335     Sinew Sliver's ability does give itself +1/+1.
#
# [52336 rows x 5 columns]

# %%
cleaned_rules = rules.drop(columns=['object', 'source', 'published_at'])
cleaned_rules
# Out:
#                                   oracle_id  \
# 0      0004ebd0-dfd6-4276-b4a6-de0003e94237
# 1      0007c283-5b7a-4c00-9ca1-b455c8dff8c3
# 2      0007c283-5b7a-4c00-9ca1-b455c8dff8c3
# 3      0007c283-5b7a-4c00-9ca1-b455c8dff8c3
# 4      000e5d65-96c3-498b-bd01-72b1a1991850
# ...                                     ...
# 52331  fffdc2ac-bde4-4e4c-a5bd-0e6c6e49ad91
# 52332  ffff90c3-63c4-4dee-a21d-6b2b113f4f80
# 52333  ffff90c3-63c4-4dee-a21d-6b2b113f4f80
# 52334  ffff90c3-63c4-4dee-a21d-6b2b113f4f80
# 52335  ffff90c3-63c4-4dee-a21d-6b2b113f4f80
#
#                                                  comment
# 0      If there are two of these on the battlefield, ...
# 1      The “commander tax” increases based on how man...
# 2      Certain cards in other sets with the partner k...
# 3      If your commander isn’t in the command zone (o...
# 4      The target loses just one of the listed abilit...
# ...                                                  ...
# 52331  You divide the damage as you activate Samut’s ...
# 52332  Abilities that Slivers grant, as well as power...
# 52333  If the creature type of a Sliver changes so it...
# 52334  Because damage remains marked on a creature un...
# 52335     Sinew Sliver's ability does give itself +1/+1.
#
# [52336 rows x 2 columns]

# %%
grouped_rules = cleaned_rules.groupby(['oracle_id']).agg(lambda x: x.tolist())
grouped_rules.shape
# Out:
# (14861, 1)

# %%
final_rules_dataset = grouped_rules.copy()

# %% [markdown]
# ## Mesclagem dos conjuntos de dados

# %%
merged_dataset = final_cards_dataset.merge(final_rules_dataset, on='oracle_id', how='left')
merged_dataset.shape
# Out:
# (25497, 22)

# %%
merged_dataset
# Out:
#                                          id  \
# 0      0000579f-7b35-4ed3-b44c-db2a538066fe
# 1      00006596-1166-4a79-8443-ca9f82e6db4e
# 2      0000cd57-91fe-411f-b798-646e965eec37
# 3      0001f1ef-b957-4a55-b47f-14839cdbab6f
# 4      0002ab72-834b-4c81-82b1-0d2760ea96b0
# ...                                     ...
# 25492  ffeca7a7-2a14-4166-9e89-0f4eb94b79f5
# 25493  fff118a5-765b-4ba1-8f12-ce6f24b2459b
# 25494  fff5a09e-9276-44b8-b374-4b84aebd47cc
# 25495  fff9989f-77a3-4f73-ade6-c04306c98501
# 25496  fffe7b2b-22c3-4e6a-9b1b-c6d7b29b9f86
#
#                                   oracle_id  mana_cost  cmc  \
# 0      44623693-51d6-49ad-8cd7-140505caf02f     {5}{R}  6.0
# 1      8ae3562f-28b7-4462-96ed-be0cf7052ccc     {W}{W}  2.0
# 2      9f0d82ae-38bf-45d8-8cda-982b6ead1d72     {2}{U}  3.0
# 3      ef027846-be81-4959-a6b5-56bd01b1e68a        {W}  1.0
# 4      645b5784-a6f7-4cf3-966a-e1a51420b96b     {2}{U}  3.0
# ...                                     ...        ...  ...
# 25492  9ef24a79-fade-4c38-b63c-22983206b4ad     {1}{G}  2.0
# 25493  82c5ec8e-27be-475a-9921-ad61209fd022             0.0
# 25494  b33d2b77-f068-4fdc-a1a8-0353a35e3973   {3}{U/P}  4.0
# 25495  e2fe1847-4003-41c5-a64b-03afd888b81e  {3}{B}{B}  5.0
# 25496  d7ebd4a7-c542-469f-8a1c-d48b92fa540a  {1}{W}{W}  3.0
#
#                         type_line  \
# 0               Creature — Sliver
# 1          Creature — Kor Soldier
# 2         Creature — Siren Pirate
# 3         Creature — Human Knight
# 4                 Creature — Fish
# ...                           ...
# 25492   Creature — Centaur Shaman
# 25493                        Land
# 25494                     Sorcery
# 25495           Creature — Spirit
# 25496  Creature — Vampire Soldier
#
#                                              oracle_text power toughness  \
# 0               All Sliver creatures have double strike.     3         3
# 1      When Kor Outfitter enters the battlefield, you...     2         2
# 2      Flying\nWhen Siren Lookout enters the battlefi...     1         2
# 3      When Venerable Knight dies, put a +1/+1 counte...     2         1
# 4      Whenever you draw your second card each turn, ...     3         1
# ...                                                  ...   ...       ...
# 25492  Enchantment spells you cast cost {1} less to c...     2         2
# 25493  {T}: Add {C}.\n{1}, {T}: Add one mana of any c...   NaN       NaN
# 25494  ({U/P} can be paid with either {U} or 2 life.)...   NaN       NaN
# 25495  Morbid — When Morkrut Banshee enters the battl...     4         4
# 25496                                             Flying     2         3
#
#       colors color_identity           keywords  \
# 0        [R]            [R]                 []
# 1        [W]            [W]                 []
# 2        [U]            [U]  [Flying, Explore]
# 3        [W]            [W]                 []
# 4        [U]            [U]                 []
# ...      ...            ...                ...
# 25492    [G]            [G]                 []
# 25493     []             []                 []
# 25494    [U]            [U]      [Proliferate]
# 25495    [B]            [B]           [Morbid]
# 25496    [W]            [W]           [Flying]
#
#                                               legalities  reserved    rarity  \
# 0      {'standard': 'not_legal', 'future': 'not_legal...     False  uncommon
# 1      {'standard': 'not_legal', 'future': 'not_legal...     False    common
# 2      {'standard': 'not_legal', 'future': 'not_legal...     False    common
# 3      {'standard': 'not_legal', 'future': 'not_legal...     False  uncommon
# 4      {'standard': 'not_legal', 'future': 'not_legal...     False    common
# ...                                                  ...       ...       ...
# 25492  {'standard': 'not_legal', 'future': 'not_legal...     False      rare
# 25493  {'standard': 'not_legal', 'future': 'not_legal...     False    common
# 25494  {'standard': 'not_legal', 'future': 'not_legal...     False  uncommon
# 25495  {'standard': 'not_legal', 'future': 'not_legal...     False  uncommon
# 25496  {'standard': 'not_legal', 'future': 'not_legal...     False    common
#
#                                              flavor_text  edhrec_rank  \
# 0      "A rift opened, and our arrows were abruptly s...       6148.0
# 1      "We take only what we need to survive. Believe...      15131.0
# 2                                                    NaN      13541.0
# 3      "May this blade guide you on your great journe...      13135.0
# 4      The problem wasn't that fish had learned how t...      22283.0
# ...                                                  ...          ...
# 25492  The distinction of bearing the gods' banner is...       1323.0
# 25493  Philosophers speak of a place where myths wash...       4668.0
# 25494                                                NaN        796.0
# 25495  "Let go your grudges, or risk wandering the bo...      18503.0
# 25496  "We have come at last to this holiest of holy ...      18667.0
#
#        penny_rank       produced_mana loyalty  life_modifier  hand_modifier  \
# 0         11341.0                 NaN     NaN            NaN            NaN
# 1          4905.0                 NaN     NaN            NaN            NaN
# 2          8653.0                 NaN     NaN            NaN            NaN
# 3          1504.0                 NaN     NaN            NaN            NaN
# 4             NaN                 NaN     NaN            NaN            NaN
# ...           ...                 ...     ...            ...            ...
# 25492      3194.0                 NaN     NaN            NaN            NaN
# 25493      3086.0  [B, C, G, R, U, W]     NaN            NaN            NaN
# 25494      2168.0                 NaN     NaN            NaN            NaN
# 25495     12122.0                 NaN     NaN            NaN            NaN
# 25496     10293.0                 NaN     NaN            NaN            NaN
#
#                                                  comment
# 0      [Abilities that Slivers grant, as well as powe...
# 1      [You may target Kor Outfitter with its ability...
# 2      [If a resolving spell or ability instructs a s...
# 3      [If a Knight you control is dealt lethal damag...
# 4      [If a spell or ability causes you to put a car...
# ...                                                  ...
# 25492  [Herald of the Pantheon can reduce alternative...
# 25493                                                NaN
# 25494  [If you're at 1 life or less, you can't pay 2 ...
# 25495  [If there are no other creatures on the battle...
# 25496                                                NaN
#
# [25497 rows x 22 columns]

# %%
final_merged_dataset = merged_dataset.drop(columns=['id', 'oracle_id'])
final_merged_dataset.shape
# Out:
# (25497, 20)

# %%
final_merged_dataset.head(20)
# Out:
#     mana_cost  cmc                        type_line  \
# 0      {5}{R}  6.0                Creature — Sliver
# 1      {W}{W}  2.0           Creature — Kor Soldier
# 2      {2}{U}  3.0          Creature — Siren Pirate
# 3         {W}  1.0          Creature — Human Knight
# 4      {2}{U}  3.0                  Creature — Fish
# 5      {1}{U}  2.0           Creature — Bird Wizard
# 6      {2}{B}  3.0            Creature — Snake Wall
# 7      {5}{G}  6.0          Creature — Lizard Hydra
# 8      {2}{G}  3.0            Creature — Human Monk
# 9   {1}{B}{B}  3.0      Creature — Vampire Assassin
# 10     {3}{G}  4.0           Creature — Elf Warrior
# 11     {3}{G}  4.0                          Instant
# 12             0.0                      Land — Gate
# 13        {W}  1.0                          Instant
# 14        {W}  1.0          Creature — Human Knight
# 15     {1}{B}  2.0          Creature — Human Knight
# 16     {2}{B}  3.0                          Instant
# 17        {3}  3.0   Legendary Artifact — Equipment
# 18     {1}{U}  2.0           Creature — Human Rogue
# 19  {W}{U}{B}  3.0  Legendary Planeswalker — Dakkon
#
#                                           oracle_text power toughness  \
# 0            All Sliver creatures have double strike.     3         3
# 1   When Kor Outfitter enters the battlefield, you...     2         2
# 2   Flying\nWhen Siren Lookout enters the battlefi...     1         2
# 3   When Venerable Knight dies, put a +1/+1 counte...     2         1
# 4   Whenever you draw your second card each turn, ...     3         1
# 5   Kicker {R} (You may pay an additional {R} as y...     2         1
# 6   Defender (This creature can't attack.)\n{3}: D...     2         4
# 7   Reach\nWhen Whiptongue Hydra enters the battle...     4         4
# 8   Reach\nWar Historian has indestructible as lon...     3         3
# 9   Lifelink\nWhen Blood Operative enters the batt...     3         1
# 10  Parley — When Selvala's Enforcer enters the ba...     2         2
# 11  Create a 3/3 green Beast creature token for ea...   NaN       NaN
# 12  Orzhov Guildgate enters the battlefield tapped...   NaN       NaN
# 13  Creatures you control get +1/+1 until end of t...   NaN       NaN
# 14  Defender (This creature can't attack.)\nAs lon...     2         3
# 15  Flanking (Whenever a creature without flanking...     2         2
# 16  Target creature gets -1/-1 until end of turn.\...   NaN       NaN
# 17  Equipped creature gets +1/+1 for each creature...   NaN       NaN
# 18  Hexproof (This creature can't be the target of...     1         1
# 19  Dakkon, Shadow Slayer enters the battlefield w...   NaN       NaN
#
#        colors color_identity           keywords  \
# 0         [R]            [R]                 []
# 1         [W]            [W]                 []
# 2         [U]            [U]  [Flying, Explore]
# 3         [W]            [W]                 []
# 4         [U]            [U]                 []
# 5         [U]         [R, U]   [Kicker, Flying]
# 6         [B]            [B]         [Defender]
# 7         [G]            [G]            [Reach]
# 8         [G]            [G]            [Reach]
# 9         [B]            [B]         [Lifelink]
# 10        [G]            [G]           [Parley]
# 11        [G]            [G]                 []
# 12         []         [B, W]                 []
# 13        [W]            [W]                 []
# 14        [W]            [W]         [Defender]
# 15        [B]            [B]         [Flanking]
# 16        [B]            [B]                 []
# 17         []             []            [Equip]
# 18        [U]            [U]         [Hexproof]
# 19  [B, U, W]      [B, U, W]          [Surveil]
#
#                                            legalities  reserved    rarity  \
# 0   {'standard': 'not_legal', 'future': 'not_legal...     False  uncommon
# 1   {'standard': 'not_legal', 'future': 'not_legal...     False    common
# 2   {'standard': 'not_legal', 'future': 'not_legal...     False    common
# 3   {'standard': 'not_legal', 'future': 'not_legal...     False  uncommon
# 4   {'standard': 'not_legal', 'future': 'not_legal...     False    common
# 5   {'standard': 'legal', 'future': 'legal', 'hist...     False  uncommon
# 6   {'standard': 'not_legal', 'future': 'not_legal...     False  uncommon
# 7   {'standard': 'not_legal', 'future': 'not_legal...     False      rare
# 8   {'standard': 'legal', 'future': 'legal', 'hist...     False    common
# 9   {'standard': 'not_legal', 'future': 'not_legal...     False      rare
# 10  {'standard': 'not_legal', 'future': 'not_legal...     False    common
# 11  {'standard': 'not_legal', 'future': 'not_legal...     False      rare
# 12  {'standard': 'not_legal', 'future': 'not_legal...     False    common
# 13  {'standard': 'not_legal', 'future': 'not_legal...     False    common
# 14  {'standard': 'not_legal', 'future': 'not_legal...     False  uncommon
# 15  {'standard': 'not_legal', 'future': 'not_legal...     False    common
# 16  {'standard': 'not_legal', 'future': 'not_legal...     False    common
# 17  {'standard': 'not_legal', 'future': 'not_legal...     False      rare
# 18  {'standard': 'not_legal', 'future': 'not_legal...     False  uncommon
# 19  {'standard': 'not_legal', 'future': 'not_legal...     False    mythic
#
#                                           flavor_text  edhrec_rank  \
# 0   "A rift opened, and our arrows were abruptly s...       6148.0
# 1   "We take only what we need to survive. Believe...      15131.0
# 2                                                 NaN      13541.0
# 3   "May this blade guide you on your great journe...      13135.0
# 4   The problem wasn't that fish had learned how t...      22283.0
# 5                                                 NaN      19347.0
# 6   What wall can never be climbed, but is always ...      23030.0
# 7   "Where'd all the birds go?"\n—Kaldrin, jungle ...       4075.0
# 8   All children on Kamigawa learn of the Kami War...      23200.0
# 9                                                 NaN      13992.0
# 10                                                NaN      17547.0
# 11         A scavenger's favorite appetizer is death.       5474.0
# 12  Enter to find wealth, security, and eternal li...       1231.0
# 13  "Honor rides before us. All we have to do is c...      15477.0
# 14        Even the greatest hero begins with nothing.      15457.0
# 15  In troubled times, there are few greater sorro...      23329.0
# 16  When one of the Patriarch's champions displeas...      17427.0
# 17                                                NaN          NaN
# 18  "All that concerns me is the vampires' sense o...       1429.0
# 19                                                NaN       4167.0
#
#     penny_rank produced_mana loyalty  life_modifier  hand_modifier  \
# 0      11341.0           NaN     NaN            NaN            NaN
# 1       4905.0           NaN     NaN            NaN            NaN
# 2       8653.0           NaN     NaN            NaN            NaN
# 3       1504.0           NaN     NaN            NaN            NaN
# 4          NaN           NaN     NaN            NaN            NaN
# 5       7832.0           NaN     NaN            NaN            NaN
# 6          NaN           NaN     NaN            NaN            NaN
# 7          NaN           NaN     NaN            NaN            NaN
# 8          NaN           NaN     NaN            NaN            NaN
# 9       7571.0           NaN     NaN            NaN            NaN
# 10         NaN           NaN     NaN            NaN            NaN
# 11      5451.0           NaN     NaN            NaN            NaN
# 12       949.0        [B, W]     NaN            NaN            NaN
# 13      4098.0           NaN     NaN            NaN            NaN
# 14         NaN           NaN     NaN            NaN            NaN
# 15      4261.0           NaN     NaN            NaN            NaN
# 16         NaN           NaN     NaN            NaN            NaN
# 17         NaN           NaN     NaN            NaN            NaN
# 18      2191.0           NaN     NaN            NaN            NaN
# 19       640.0           NaN       0            NaN            NaN
#
#                                               comment
# 0   [Abilities that Slivers grant, as well as powe...
# 1   [You may target Kor Outfitter with its ability...
# 2   [If a resolving spell or ability instructs a s...
# 3   [If a Knight you control is dealt lethal damag...
# 4   [If a spell or ability causes you to put a car...
# 5                                                 NaN
# 6                                                 NaN
# 7   [A creature with indestructible or a creature ...
# 8   [War Historian’s last ability starts to apply ...
# 9   [An ability that triggers “whenever you survei...
# 10  [If Selvala’s Enforcer leaves the battlefield ...
# 11  [Fresh Meat counts all creatures you owned tha...
# 12  [Gate is not a basic land type., The subtype G...
# 13  [Charge affects only creatures you control at ...
# 14  [Once Novice Knight has attacked, it will rema...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN

# %% [markdown]
# ## Pré-processamento do dataset

# %% [markdown]
# ### Correção do tipo

# %%
# final_merged_dataset[['type', 'subtype']] = final_merged_dataset['type_line'].str.split(' — ', expand=True)
# final_merged_dataset
splitted_type_dataset = final_merged_dataset.copy()
splitted_type_dataset[['type', 'subtype']] = splitted_type_dataset['type_line'].str.split('—', expand=True)
splitted_type_dataset.shape
# Out:
# (25497, 22)

# %%
# supertypes = [
# 'Basic',
# 'Legendary',
# 'Snow',
# 'World'
# ]

# # card_set_standardized_types = card_set_without_duplicates[card_set_without_duplicates['type_line'].str.contains('|'.join(mtg_card_types))]

# test[test['type'].str.contains('|'.join(supertypes))]

# %%
splitted_type_dataset.drop(columns=[ 'type_line'], inplace=True)
splitted_type_dataset
# Out:
#        mana_cost  cmc                                        oracle_text  \
# 0         {5}{R}  6.0           All Sliver creatures have double strike.
# 1         {W}{W}  2.0  When Kor Outfitter enters the battlefield, you...
# 2         {2}{U}  3.0  Flying\nWhen Siren Lookout enters the battlefi...
# 3            {W}  1.0  When Venerable Knight dies, put a +1/+1 counte...
# 4         {2}{U}  3.0  Whenever you draw your second card each turn, ...
# ...          ...  ...                                                ...
# 25492     {1}{G}  2.0  Enchantment spells you cast cost {1} less to c...
# 25493             0.0  {T}: Add {C}.\n{1}, {T}: Add one mana of any c...
# 25494   {3}{U/P}  4.0  ({U/P} can be paid with either {U} or 2 life.)...
# 25495  {3}{B}{B}  5.0  Morbid — When Morkrut Banshee enters the battl...
# 25496  {1}{W}{W}  3.0                                             Flying
#
#       power toughness colors color_identity           keywords  \
# 0         3         3    [R]            [R]                 []
# 1         2         2    [W]            [W]                 []
# 2         1         2    [U]            [U]  [Flying, Explore]
# 3         2         1    [W]            [W]                 []
# 4         3         1    [U]            [U]                 []
# ...     ...       ...    ...            ...                ...
# 25492     2         2    [G]            [G]                 []
# 25493   NaN       NaN     []             []                 []
# 25494   NaN       NaN    [U]            [U]      [Proliferate]
# 25495     4         4    [B]            [B]           [Morbid]
# 25496     2         3    [W]            [W]           [Flying]
#
#                                               legalities  reserved    rarity  \
# 0      {'standard': 'not_legal', 'future': 'not_legal...     False  uncommon
# 1      {'standard': 'not_legal', 'future': 'not_legal...     False    common
# 2      {'standard': 'not_legal', 'future': 'not_legal...     False    common
# 3      {'standard': 'not_legal', 'future': 'not_legal...     False  uncommon
# 4      {'standard': 'not_legal', 'future': 'not_legal...     False    common
# ...                                                  ...       ...       ...
# 25492  {'standard': 'not_legal', 'future': 'not_legal...     False      rare
# 25493  {'standard': 'not_legal', 'future': 'not_legal...     False    common
# 25494  {'standard': 'not_legal', 'future': 'not_legal...     False  uncommon
# 25495  {'standard': 'not_legal', 'future': 'not_legal...     False  uncommon
# 25496  {'standard': 'not_legal', 'future': 'not_legal...     False    common
#
#                                              flavor_text  edhrec_rank  \
# 0      "A rift opened, and our arrows were abruptly s...       6148.0
# 1      "We take only what we need to survive. Believe...      15131.0
# 2                                                    NaN      13541.0
# 3      "May this blade guide you on your great journe...      13135.0
# 4      The problem wasn't that fish had learned how t...      22283.0
# ...                                                  ...          ...
# 25492  The distinction of bearing the gods' banner is...       1323.0
# 25493  Philosophers speak of a place where myths wash...       4668.0
# 25494                                                NaN        796.0
# 25495  "Let go your grudges, or risk wandering the bo...      18503.0
# 25496  "We have come at last to this holiest of holy ...      18667.0
#
#        penny_rank       produced_mana loyalty  life_modifier  hand_modifier  \
# 0         11341.0                 NaN     NaN            NaN            NaN
# 1          4905.0                 NaN     NaN            NaN            NaN
# 2          8653.0                 NaN     NaN            NaN            NaN
# 3          1504.0                 NaN     NaN            NaN            NaN
# 4             NaN                 NaN     NaN            NaN            NaN
# ...           ...                 ...     ...            ...            ...
# 25492      3194.0                 NaN     NaN            NaN            NaN
# 25493      3086.0  [B, C, G, R, U, W]     NaN            NaN            NaN
# 25494      2168.0                 NaN     NaN            NaN            NaN
# 25495     12122.0                 NaN     NaN            NaN            NaN
# 25496     10293.0                 NaN     NaN            NaN            NaN
#
#                                                  comment       type  \
# 0      [Abilities that Slivers grant, as well as powe...  Creature
# 1      [You may target Kor Outfitter with its ability...  Creature
# 2      [If a resolving spell or ability instructs a s...  Creature
# 3      [If a Knight you control is dealt lethal damag...  Creature
# 4      [If a spell or ability causes you to put a car...  Creature
# ...                                                  ...        ...
# 25492  [Herald of the Pantheon can reduce alternative...  Creature
# 25493                                                NaN       Land
# 25494  [If you're at 1 life or less, you can't pay 2 ...    Sorcery
# 25495  [If there are no other creatures on the battle...  Creature
# 25496                                                NaN  Creature
#
#                 subtype
# 0                Sliver
# 1           Kor Soldier
# 2          Siren Pirate
# 3          Human Knight
# 4                  Fish
# ...                 ...
# 25492    Centaur Shaman
# 25493              None
# 25494              None
# 25495            Spirit
# 25496   Vampire Soldier
#
# [25497 rows x 21 columns]

# %% [markdown]
# ### Cálculo de devoção

# %%
def calcDevotion(devotion):

    if not devotion:
        return 0

    devotion = str(devotion)

    devotions = []
    devotions.append(len(re.findall("[w]", devotion, re.IGNORECASE)))
    devotions.append(len(re.findall("[r]", devotion, re.IGNORECASE)))
    devotions.append(len(re.findall("[u]", devotion, re.IGNORECASE)))
    devotions.append(len(re.findall("[g]", devotion, re.IGNORECASE)))
    devotions.append(len(re.findall("[b]", devotion, re.IGNORECASE)))

    return max(devotions)

# %%
devotion_data_set = splitted_type_dataset.copy()
devotion_data_set['devotion'] = devotion_data_set.apply(lambda x : calcDevotion(x.mana_cost), axis=1)
devotion_data_set.shape
# Out:
# (25497, 22)

# %% [markdown]
# ### Cálculo de mana phyrexiano

# %%
def checkPhyrexianMana(manaCost):

    if not manaCost:
        return 0

    return 1 if re.search('P', manaCost) else 0

# %%
phyrexian_mana_data_set = devotion_data_set.copy()
phyrexian_mana_data_set['phyrexian_mana'] = phyrexian_mana_data_set.apply(lambda x : checkPhyrexianMana(x.mana_cost), axis=1)
phyrexian_mana_data_set.drop(columns='mana_cost', inplace=True)
phyrexian_mana_data_set.shape
# Out:
# (25497, 22)

# %% [markdown]
# ### Cálculo do _flavor text_

# %%
def calcTextLen(txt):
    
    if isinstance(txt, str):
        return len(txt)

    return 0

# %%
flavor_data_set = phyrexian_mana_data_set.copy()
flavor_data_set['flavor_size'] = flavor_data_set.apply(lambda x : calcTextLen(x.flavor_text), axis=1)
flavor_data_set.drop(columns=['flavor_text'], inplace=True)
flavor_data_set.shape
# Out:
# (25497, 22)

# %% [markdown]
# ### Cálculo do número de habilidades

# %%
def calcAbilities(key_words: list, oracle_text: str):

    if key_words and not oracle_text:
        return len(key_words)

    if oracle_text and not key_words:
        return 1

    if key_words and oracle_text:
        for word in key_words:
            ¡

    return 0

# %%
text = 'Flying\nWhen Siren Lookout enters the battlefield, it explores.'
pattern = ['flying','explore']
len(re.match(pattern, text))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 3
#       1 text = 'Flying\nWhen Siren Lookout enters the battlefield, it explores.'
#       2 pattern = ['flying','explore']
# ----> 3 len(re.match(pattern, text))
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/tcc_venv/lib/python3.8/re.py:191, in match(pattern, string, flags)
#     188 def match(pattern, string, flags=0):
#     189     """Try to apply the pattern at the start of the string, returning
#     190     a Match object, or None if no match was found."""
# --> 191     return _compile(pattern, flags).match(string)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/tcc_venv/lib/python3.8/re.py:294, in _compile(pattern, flags)
#     292     flags = flags.value
#     293 try:
# --> 294     return _cache[type(pattern), pattern, flags]
#     295 except KeyError:
#     296     pass
#
# TypeError: unhashable type: 'list'

# %%
abilities_dataset = flavor_data_set.copy()
abilities_dataset['abilities'] = abilities_dataset.apply(lambda row: calcAbilities(row['keywords']), axis=1)
abilities_dataset.drop(columns=['keywords'], inplace=True)
abilities_dataset.shape
# Out:
# (25497, 22)

# %% [markdown]
# ### Cálculo de produção de mana
#
# Aqui haviam duas abordagens:
#
# 1. Assumir um booleano que representa se uma carta é ou não capaz de produzir mana;
# 2. Definir quantas cores diferentes de mana uma dada carta pode gerar (sendo, portanto, um valor numérico - e não lógico como acima - que pode assumir o intervalo entre 0 e 5, inclusos)
#
# Num primeiro momento, optou-se pela abordagem 1.

# %%
def canProduceMana(producedMana):

    if isinstance(producedMana, list):
        return 1 if len(producedMana) > 0 else 0

    return 0 if not producedMana or math.isnan(producedMana) else 0

# %%
produced_mana_dataset = abilities_dataset.copy()
produced_mana_dataset['produced_mana'] = produced_mana_dataset.apply(lambda row: canProduceMana(row['produced_mana']), axis=1)
produced_mana_dataset
# Out:
#        cmc                                        oracle_text power toughness  \
# 0      6.0           All Sliver creatures have double strike.     3         3
# 1      2.0  When Kor Outfitter enters the battlefield, you...     2         2
# 2      3.0  Flying\nWhen Siren Lookout enters the battlefi...     1         2
# 3      1.0  When Venerable Knight dies, put a +1/+1 counte...     2         1
# 4      3.0  Whenever you draw your second card each turn, ...     3         1
# ...    ...                                                ...   ...       ...
# 25492  2.0  Enchantment spells you cast cost {1} less to c...     2         2
# 25493  0.0  {T}: Add {C}.\n{1}, {T}: Add one mana of any c...   NaN       NaN
# 25494  4.0  ({U/P} can be paid with either {U} or 2 life.)...   NaN       NaN
# 25495  5.0  Morbid — When Morkrut Banshee enters the battl...     4         4
# 25496  3.0                                             Flying     2         3
#
#       colors color_identity  \
# 0        [R]            [R]
# 1        [W]            [W]
# 2        [U]            [U]
# 3        [W]            [W]
# 4        [U]            [U]
# ...      ...            ...
# 25492    [G]            [G]
# 25493     []             []
# 25494    [U]            [U]
# 25495    [B]            [B]
# 25496    [W]            [W]
#
#                                               legalities  reserved    rarity  \
# 0      {'standard': 'not_legal', 'future': 'not_legal...     False  uncommon
# 1      {'standard': 'not_legal', 'future': 'not_legal...     False    common
# 2      {'standard': 'not_legal', 'future': 'not_legal...     False    common
# 3      {'standard': 'not_legal', 'future': 'not_legal...     False  uncommon
# 4      {'standard': 'not_legal', 'future': 'not_legal...     False    common
# ...                                                  ...       ...       ...
# 25492  {'standard': 'not_legal', 'future': 'not_legal...     False      rare
# 25493  {'standard': 'not_legal', 'future': 'not_legal...     False    common
# 25494  {'standard': 'not_legal', 'future': 'not_legal...     False  uncommon
# 25495  {'standard': 'not_legal', 'future': 'not_legal...     False  uncommon
# 25496  {'standard': 'not_legal', 'future': 'not_legal...     False    common
#
#        edhrec_rank  penny_rank  produced_mana loyalty  life_modifier  \
# 0           6148.0     11341.0              0     NaN            NaN
# 1          15131.0      4905.0              0     NaN            NaN
# 2          13541.0      8653.0              0     NaN            NaN
# 3          13135.0      1504.0              0     NaN            NaN
# 4          22283.0         NaN              0     NaN            NaN
# ...            ...         ...            ...     ...            ...
# 25492       1323.0      3194.0              0     NaN            NaN
# 25493       4668.0      3086.0              1     NaN            NaN
# 25494        796.0      2168.0              0     NaN            NaN
# 25495      18503.0     12122.0              0     NaN            NaN
# 25496      18667.0     10293.0              0     NaN            NaN
#
#        hand_modifier                                            comment  \
# 0                NaN  [Abilities that Slivers grant, as well as powe...
# 1                NaN  [You may target Kor Outfitter with its ability...
# 2                NaN  [If a resolving spell or ability instructs a s...
# 3                NaN  [If a Knight you control is dealt lethal damag...
# 4                NaN  [If a spell or ability causes you to put a car...
# ...              ...                                                ...
# 25492            NaN  [Herald of the Pantheon can reduce alternative...
# 25493            NaN                                                NaN
# 25494            NaN  [If you're at 1 life or less, you can't pay 2 ...
# 25495            NaN  [If there are no other creatures on the battle...
# 25496            NaN                                                NaN
#
#             type           subtype  devotion  phyrexian_mana  flavor_size  \
# 0      Creature             Sliver         1               0          228
# 1      Creature        Kor Soldier         2               0           71
# 2      Creature       Siren Pirate         1               0            0
# 3      Creature       Human Knight         1               0           71
# 4      Creature               Fish         1               0           99
# ...          ...               ...       ...             ...          ...
# 25492  Creature     Centaur Shaman         1               0          100
# 25493       Land              None         0               0           86
# 25494    Sorcery              None         1               1            0
# 25495  Creature             Spirit         2               0          104
# 25496  Creature    Vampire Soldier         2               0          107
#
#        abilities
# 0              0
# 1              0
# 2              2
# 3              0
# 4              0
# ...          ...
# 25492          0
# 25493          0
# 25494          1
# 25495          1
# 25496          1
#
# [25497 rows x 22 columns]

# %%
produced_mana_dataset.columns
# Out:
# Index(['cmc', 'oracle_text', 'power', 'toughness', 'colors', 'color_identity',
#        'legalities', 'reserved', 'rarity', 'edhrec_rank', 'penny_rank',
#        'produced_mana', 'loyalty', 'life_modifier', 'hand_modifier', 'comment',
#        'type', 'subtype', 'devotion', 'phyrexian_mana', 'flavor_size',
#        'abilities'],
#       dtype='object')
